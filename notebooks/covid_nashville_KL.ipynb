# %% [markdown]
# ### Covid Nashville Project

# %% [markdown]
# #### Import library

# %%
import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sns
from credentials import user, password, server

# %% [markdown]
# #### Formatting

# %%
# %matplotlib inline

# %%
engine = create_engine("postgres+psycopg2://"+user+":"\
                       +password+"@"\
                       +server+":5432/covid_data")

# %%
colleges = pd.read_sql("SELECT * FROM colleges;", con=engine)
colleges.head()
# Out:
#          date    state      county        city ipeds_id  \
# 0  2020-11-05  Alabama     Madison  Huntsville   100654
# 1  2020-11-05  Alabama  Montgomery  Montgomery   100724
# 2  2020-11-05  Alabama   Limestone      Athens   100812
# 3  2020-11-05  Alabama         Lee      Auburn   100858
# 4  2020-11-05  Alabama  Montgomery  Montgomery   100830
#
#                            college   cases notes
# 0           Alabama A&M University    41.0  None
# 1         Alabama State University     NaN  None
# 2          Athens State University    23.0  None
# 3                Auburn University  2047.0  None
# 4  Auburn University at Montgomery    80.0  None

# %%
mask_use = pd.read_sql("SELECT * FROM mask_use;", con=engine)
mask_use.head()
# Out:
#   county_fips  never  rarely  sometimes  frequently  always
# 0       01001  0.053   0.074      0.134       0.295   0.444
# 1       01003  0.083   0.059      0.098       0.323   0.436
# 2       01005  0.067   0.121      0.120       0.201   0.491
# 3       01007  0.020   0.034      0.096       0.278   0.572
# 4       01009  0.053   0.114      0.180       0.194   0.459

# %%
states = pd.read_sql("SELECT * FROM states;", con=engine)
states.head()
# Out:
#          date       state fips  cases  deaths
# 0  2020-01-21  Washington   53      1       0
# 1  2020-01-22  Washington   53      1       0
# 2  2020-01-23  Washington   53      1       0
# 3  2020-01-24    Illinois   17      1       0
# 4  2020-01-24  Washington   53      1       0

# %%
counties = pd.read_sql("SELECT * FROM counties;", con=engine)
counties.head()
# Out:
#          date     county       state   fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061      1       0
# 1  2020-01-22  Snohomish  Washington  53061      1       0
# 2  2020-01-23  Snohomish  Washington  53061      1       0
# 3  2020-01-24       Cook    Illinois  17031      1       0
# 4  2020-01-24  Snohomish  Washington  53061      1       0

# %%
us_totals = pd.read_sql("SELECT * FROM us_totals;", con=engine)
us_totals.head()
# Out:
#          date  cases  deaths
# 0  2020-01-21      1       0
# 1  2020-01-22      1       0
# 2  2020-01-23      1       0
# 3  2020-01-24      2       0
# 4  2020-01-25      3       0

# %%
businesses_df = pd.read_csv('../data/businesses.csv')
businesses_df.head()
# Out:
#                             address                          vicinity  \
# 0   2440 COUCHVILLE PIKE, Nashville   2440 Couchville Pike, Nashville
# 1       1613 Buchanan St, Nashville   1613 Buchanan Street, Nashville
# 2       1613 Buchanan St, Nashville   1613 Buchanan Street, Nashville
# 3       1613 Buchanan St, Nashville   1613 Buchanan Street, Nashville
# 4  306 White Bridge Pike, Nashville  306 White Bridge Pike, Nashville
#
#                                  name  \
# 0            Wilson Sporting Goods Co
# 1              Coin Cloud Bitcoin ATM
# 2                      Discounts Mart
# 3                   Northwest Liquors
# 4  Suds Up Car Wash of West Nashville
#
#                                                 type
# 0             ['point_of_interest', 'establishment']
# 1  ['atm', 'finance', 'point_of_interest', 'estab...
# 2  ['convenience_store', 'food', 'point_of_intere...
# 3  ['liquor_store', 'point_of_interest', 'store',...
# 4  ['car_wash', 'point_of_interest', 'establishme...

# %%
type(businesses_df)
# Out:
# pandas.core.frame.DataFrame

# %%
clusters_df = pd.read_csv('../data/clusters.csv')
clusters_df.head()
# Out:
#                             Cluster Name     Facility Type Cluster Start Date  \
# 0                     Vanderbilt Parties  Social Gathering          3/11/2020
# 1               Event at Clementine Hall  Social Gathering          3/14/2020
# 2                      Religious Retreat  Social Gathering          3/25/2020
# 3    The Health Center at Richland Place              LTCF           4/3/2020
# 4  Trevecca Center for Rehab and Healing              LTCF           4/4/2020
#
#    # Cases   Latitude  Longitude
# 0       49  36.144703 -86.802655
# 1       23  36.152444 -86.844583
# 2       18        NaN        NaN
# 3       47  36.128750 -86.817345
# 4      102  36.144562 -86.754560

# %%
hubnash_df = pd.read_csv('../data/hubNashville__311__Service_Requests.csv', low_memory=False)
hubnash_df.head()
# Out:
#    Request #  Status                            Request Type  \
# 0     353977  Closed                                COVID-19
# 1     367021  Closed  Resolved by hubNashville on First Call
# 2     419194  Closed              Streets, Roads & Sidewalks
# 3     366600  Closed  Resolved by hubNashville on First Call
# 4     408945  Closed  Resolved by hubNashville on First Call
#
#                                      Subrequest Type  \
# 0  COVID-19 - Submit Input about The Plan to Reop...
# 1             Resolved by hubNashville on First Call
# 2                           Remove debris in roadway
# 3             Resolved by hubNashville on First Call
# 4             Resolved by hubNashville on First Call
#
#                           Additional Subrequest Type      Date / Time Opened  \
# 0  COVID-19 - Submit Input about The Plan to Reop...  04/28/2020 02:33:22 PM
# 1             Resolved by hubNashville on First Call  05/13/2020 09:00:52 PM
# 2                                            Roadway  07/17/2020 03:21:03 PM
# 3             Resolved by hubNashville on First Call  05/13/2020 04:04:14 PM
# 4             Resolved by hubNashville on First Call  07/06/2020 05:57:28 PM
#
#        Date / Time Closed          Request Origin System of Origin ID  \
# 0  04/28/2020 02:33:22 PM  hubNashville Community                 NaN
# 1  05/13/2020 09:00:52 PM                   Phone                 NaN
# 2  07/28/2020 04:06:19 PM  hubNashville Community                 NaN
# 3  05/13/2020 04:04:14 PM                   Phone                 NaN
# 4  07/06/2020 05:57:28 PM                   Phone                 NaN
#
#   Contact Type  ...  State Issue  Parent Request  Closed When Created  \
# 0          NaN  ...        False             NaN                 True
# 1          NaN  ...        False             NaN                 True
# 2          NaN  ...        False             NaN                False
# 3          NaN  ...        False             NaN                 True
# 4          NaN  ...        False             NaN                 True
#
#                        Address       City Council District    ZIP   Latitude  \
# 0                          NaN        NaN              NaN    NaN        NaN
# 1                          NaN        NaN              NaN    NaN        NaN
# 2  Lafayette St & Claiborne St  NASHVILLE             17.0  37210  36.148412
# 3                          NaN        NaN              NaN    NaN        NaN
# 4                          NaN        NaN              NaN    NaN        NaN
#
#    Longitude           Mapped Location
# 0        NaN                       NaN
# 1        NaN                       NaN
# 2 -86.761179  (36.1484116, -86.761179)
# 3        NaN                       NaN
# 4        NaN                       NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Part 2.
#
# Use sqlalchemy to load data for Nashville from the counties table in the covid_data database on AWS. Explore this data. Is there a relationship between the number of cases over time and the number of violations reported over time?

# %%
tennessee_counties = counties[counties['state'] == 'Tennessee']
tennessee_counties.head()
# Out:
#            date      county      state   fips  cases  deaths
# 570  2020-03-05  Williamson  Tennessee  47187      1       0
# 639  2020-03-06  Williamson  Tennessee  47187      1       0
# 731  2020-03-07  Williamson  Tennessee  47187      1       0
# 841  2020-03-08    Davidson  Tennessee  47037      1       0
# 842  2020-03-08      Shelby  Tennessee  47157      1       0

# %%
davidson_cases = tennessee_counties[tennessee_counties['county'] == 'Davidson']
davidson_cases
# Out:
#               date    county      state   fips  cases  deaths
# 841     2020-03-08  Davidson  Tennessee  47037      1       0
# 970     2020-03-09  Davidson  Tennessee  47037      1       0
# 1127    2020-03-10  Davidson  Tennessee  47037      1       0
# 1323    2020-03-11  Davidson  Tennessee  47037      2       0
# 1569    2020-03-12  Davidson  Tennessee  47037      6       0
# ...            ...       ...        ...    ...    ...     ...
# 725079  2020-11-12  Davidson  Tennessee  47037  38802     374
# 728324  2020-11-13  Davidson  Tennessee  47037  39101     379
# 731568  2020-11-14  Davidson  Tennessee  47037  39411     380
# 734814  2020-11-15  Davidson  Tennessee  47037  39843     382
# 738059  2020-11-16  Davidson  Tennessee  47037  40433     387
#
# [254 rows x 6 columns]

# %%
davidson_cases.dtypes
# Out:
# date      object
# county    object
# state     object
# fips      object
# cases      int64
# deaths     int64
# dtype: object

# %%
davidson_cases = davidson_cases.reset_index(drop=True)
davidson_cases.head()
# Out:
#          date    county      state   fips  cases  deaths
# 0  2020-03-08  Davidson  Tennessee  47037      1       0
# 1  2020-03-09  Davidson  Tennessee  47037      1       0
# 2  2020-03-10  Davidson  Tennessee  47037      1       0
# 3  2020-03-11  Davidson  Tennessee  47037      2       0
# 4  2020-03-12  Davidson  Tennessee  47037      6       0

# %%
# converting 'date' from object to datetime
# davidson_cases['date'] = pd.to_datetime(davidson_cases['date'], format='%Y%m%d')

#Get the month change to datetimeto datetime format
davidson_cases['month'] = pd.DatetimeIndex(davidson_cases['date']).month
davidson_cases
# Out:
#            date    county      state   fips  cases  deaths  month
# 0    2020-03-08  Davidson  Tennessee  47037      1       0      3
# 1    2020-03-09  Davidson  Tennessee  47037      1       0      3
# 2    2020-03-10  Davidson  Tennessee  47037      1       0      3
# 3    2020-03-11  Davidson  Tennessee  47037      2       0      3
# 4    2020-03-12  Davidson  Tennessee  47037      6       0      3
# ..          ...       ...        ...    ...    ...     ...    ...
# 249  2020-11-12  Davidson  Tennessee  47037  38802     374     11
# 250  2020-11-13  Davidson  Tennessee  47037  39101     379     11
# 251  2020-11-14  Davidson  Tennessee  47037  39411     380     11
# 252  2020-11-15  Davidson  Tennessee  47037  39843     382     11
# 253  2020-11-16  Davidson  Tennessee  47037  40433     387     11
#
# [254 rows x 7 columns]

# %%
davidson_cases.dtypes
# Out:
# date      object
# county    object
# state     object
# fips      object
# cases      int64
# deaths     int64
# month      int64
# dtype: object

# %%
# tried to find the sum here by date, but I believe there is only one entry per day anyways in this df so it's usless

#hubnash_coivd_group_month = hubnash_covid.groupby('month')['Date_Opened'].count().reset_index()
davidson_cases_bydate = davidson_cases.groupby('month')['cases'].max().reset_index()
davidson_cases_bydate
# Out:
#    month  cases
# 0      3    541
# 1      4   2669
# 2      5   5285
# 3      6   9805
# 4      7  21060
# 5      8  25975
# 6      9  29005
# 7     10  34900
# 8     11  40433

# %%
# Lydia's code below

#Create subplot
#note for plotting exploration analysis https://towardsdatascience.com/data-visualization-cheat-sheet-with-seaborn-and-matplotlib-70cac11c6517
sns.set_style('whitegrid')
fig,ax=plt.subplots(figsize=(16,7))
#Create lineplot
chart=sns.lineplot(x=davidson_cases_bydate['month'], y=davidson_cases_bydate['cases'],ax=ax)
sns.despine(left=True)

#Customize chart
chart.set_xlabel('Month',weight='bold',fontsize=13)
chart.set_ylabel('Cases', weight='bold',fontsize=13)
chart.set_title('Monthly Covid Counts',weight='bold',fontsize=16)
chart.set_xticklabels(['','March','April','May','June','July','August','September','October','November'], rotation = 45, ha="right")
# Out:
# [Text(0, 0, ''),
#  Text(0, 0, 'March'),
#  Text(0, 0, 'April'),
#  Text(0, 0, 'May'),
#  Text(0, 0, 'June'),
#  Text(0, 0, 'July'),
#  Text(0, 0, 'August'),
#  Text(0, 0, 'September'),
#  Text(0, 0, 'October'),
#  Text(0, 0, 'November')]

# %% [markdown]
# ##### I will need to subset the hub_nashville data and then join that to the davidson df.

# %%
# subsetting the hub_nashville data and getting only the covid related ones.

hubnash_df_covidrequest = hubnash_df[hubnash_df['Request Type'] == 'COVID-19']
hubnash_df_covidrequest.head()
# Out:
#     Request #  Status Request Type  \
# 0      353977  Closed     COVID-19
# 55     407665  Closed     COVID-19
# 61     346122  Closed     COVID-19
# 86     354331  Closed     COVID-19
# 88     417138  Closed     COVID-19
#
#                                       Subrequest Type  \
# 0   COVID-19 - Submit Input about The Plan to Reop...
# 55                                 COVID-19 Questions
# 61                                COVID-19 Violations
# 86                                 COVID-19 Questions
# 88         COVID-19 Guidance for Reopening Businesses
#
#                            Additional Subrequest Type      Date / Time Opened  \
# 0   COVID-19 - Submit Input about The Plan to Reop...  04/28/2020 02:33:22 PM
# 55                                 COVID-19 Questions  07/04/2020 07:53:35 PM
# 61                                COVID-19 Violations  04/15/2020 11:33:26 AM
# 86                                 COVID-19 Questions  04/28/2020 07:32:58 PM
# 88         COVID-19 Guidance for Reopening Businesses  07/15/2020 05:11:38 PM
#
#         Date / Time Closed          Request Origin System of Origin ID  \
# 0   04/28/2020 02:33:22 PM  hubNashville Community                 NaN
# 55  07/07/2020 02:35:48 PM  hubNashville Community                 NaN
# 61  04/16/2020 02:55:01 PM  hubNashville Community                 NaN
# 86  05/08/2020 07:13:25 PM  hubNashville Community                 NaN
# 88  07/22/2020 08:59:58 PM                   Phone                 NaN
#
#    Contact Type  ...  State Issue  Parent Request  Closed When Created  \
# 0           NaN  ...        False             NaN                 True
# 55          NaN  ...        False             NaN                False
# 61          NaN  ...        False             NaN                False
# 86          NaN  ...        False             NaN                False
# 88          NaN  ...        False             NaN                False
#
#            Address       City Council District    ZIP  Latitude  Longitude  \
# 0              NaN        NaN              NaN    NaN       NaN        NaN
# 55             NaN        NaN              NaN    NaN       NaN        NaN
# 61   928 6th Ave S  NASHVILLE             17.0  37203  36.14904 -86.772273
# 86             NaN        NaN              NaN    NaN       NaN        NaN
# 88  Charlotte Pike  NASHVILLE             22.0  37209  36.11487 -86.925890
#
#                      Mapped Location
# 0                                NaN
# 55                               NaN
# 61  (36.1490396, -86.77227289999999)
# 86                               NaN
# 88             (36.11487, -86.92589)
#
# [5 rows x 21 columns]

# %%
hubnash_covid_violations = hubnash_df_covidrequest[hubnash_df_covidrequest['Subrequest Type'] == 'COVID-19 Violations']
hubnash_covid_violations.head()
# Out:
#      Request #  Status Request Type      Subrequest Type  \
# 61      346122  Closed     COVID-19  COVID-19 Violations
# 95      339374  Closed     COVID-19  COVID-19 Violations
# 110     343513  Closed     COVID-19  COVID-19 Violations
# 113     442996  Closed     COVID-19  COVID-19 Violations
# 118     339423  Closed     COVID-19  COVID-19 Violations
#
#     Additional Subrequest Type      Date / Time Opened  \
# 61         COVID-19 Violations  04/15/2020 11:33:26 AM
# 95         COVID-19 Violations  04/04/2020 06:13:59 PM
# 110        COVID-19 Violations  04/10/2020 10:40:08 AM
# 113        COVID-19 Violations  08/12/2020 02:05:29 AM
# 118        COVID-19 Violations  04/04/2020 08:12:27 PM
#
#          Date / Time Closed          Request Origin System of Origin ID  \
# 61   04/16/2020 02:55:01 PM  hubNashville Community                 NaN
# 95   04/09/2020 01:07:22 PM  hubNashville Community                 NaN
# 110  04/14/2020 07:39:09 PM  hubNashville Community                 NaN
# 113  08/12/2020 04:03:35 PM  hubNashville Community                 NaN
# 118  04/09/2020 02:21:09 PM  hubNashville Community                 NaN
#
#     Contact Type  ...  State Issue  Parent Request  Closed When Created  \
# 61           NaN  ...        False             NaN                False
# 95           NaN  ...        False             NaN                False
# 110          NaN  ...        False             NaN                False
# 113          NaN  ...        False             NaN                False
# 118          NaN  ...        False             NaN                False
#
#                  Address       City Council District    ZIP   Latitude  \
# 61         928 6th Ave S  NASHVILLE             17.0  37203  36.149040
# 95      500 Gallatin Ave  NASHVILLE              5.0  37206  36.181548
# 110  5720 Crossings Blvd        NaN              NaN    NaN  36.039608
# 113        7689 Hwy 70 S  NASHVILLE             22.0  37221  36.078933
# 118      5310 Mt View Rd    ANTIOCH             32.0  37013  36.048182
#
#      Longitude                   Mapped Location
# 61  -86.772273  (36.1490396, -86.77227289999999)
# 95  -86.749695           (36.181548, -86.749695)
# 110 -86.646541           (36.039608, -86.646541)
# 113 -86.953400  (36.07893290000001, -86.9533998)
# 118 -86.648447         (36.0481819, -86.6484474)
#
# [5 rows x 21 columns]

# %%
hubnash_covid_violations = hubnash_covid_violations.reset_index(drop=True)
hubnash_covid_violations.head()
# Out:
#    Request #  Status Request Type      Subrequest Type  \
# 0     346122  Closed     COVID-19  COVID-19 Violations
# 1     339374  Closed     COVID-19  COVID-19 Violations
# 2     343513  Closed     COVID-19  COVID-19 Violations
# 3     442996  Closed     COVID-19  COVID-19 Violations
# 4     339423  Closed     COVID-19  COVID-19 Violations
#
#   Additional Subrequest Type      Date / Time Opened      Date / Time Closed  \
# 0        COVID-19 Violations  04/15/2020 11:33:26 AM  04/16/2020 02:55:01 PM
# 1        COVID-19 Violations  04/04/2020 06:13:59 PM  04/09/2020 01:07:22 PM
# 2        COVID-19 Violations  04/10/2020 10:40:08 AM  04/14/2020 07:39:09 PM
# 3        COVID-19 Violations  08/12/2020 02:05:29 AM  08/12/2020 04:03:35 PM
# 4        COVID-19 Violations  04/04/2020 08:12:27 PM  04/09/2020 02:21:09 PM
#
#            Request Origin System of Origin ID Contact Type  ...  State Issue  \
# 0  hubNashville Community                 NaN          NaN  ...        False
# 1  hubNashville Community                 NaN          NaN  ...        False
# 2  hubNashville Community                 NaN          NaN  ...        False
# 3  hubNashville Community                 NaN          NaN  ...        False
# 4  hubNashville Community                 NaN          NaN  ...        False
#
#    Parent Request  Closed When Created              Address       City  \
# 0             NaN                False        928 6th Ave S  NASHVILLE
# 1             NaN                False     500 Gallatin Ave  NASHVILLE
# 2             NaN                False  5720 Crossings Blvd        NaN
# 3             NaN                False        7689 Hwy 70 S  NASHVILLE
# 4             NaN                False      5310 Mt View Rd    ANTIOCH
#
#   Council District    ZIP   Latitude  Longitude  \
# 0             17.0  37203  36.149040 -86.772273
# 1              5.0  37206  36.181548 -86.749695
# 2              NaN    NaN  36.039608 -86.646541
# 3             22.0  37221  36.078933 -86.953400
# 4             32.0  37013  36.048182 -86.648447
#
#                     Mapped Location
# 0  (36.1490396, -86.77227289999999)
# 1           (36.181548, -86.749695)
# 2           (36.039608, -86.646541)
# 3  (36.07893290000001, -86.9533998)
# 4         (36.0481819, -86.6484474)
#
# [5 rows x 21 columns]

# %%
hubnash_covid_violations.dtypes
# Out:
# Request #                       int64
# Status                         object
# Request Type                   object
# Subrequest Type                object
# Additional Subrequest Type     object
# Date / Time Opened             object
# Date / Time Closed             object
# Request Origin                 object
# System of Origin ID            object
# Contact Type                   object
# Preferred Language            float64
# State Issue                      bool
# Parent Request                float64
# Closed When Created              bool
# Address                        object
# City                           object
# Council District              float64
# ZIP                            object
# Latitude                      float64
# Longitude                     float64
# Mapped Location                object
# dtype: object

# %%
# converting to datetime

hubnash_covid_violations['date'] = pd.DatetimeIndex(hubnash_covid_violations['Date / Time Opened']).date
hubnash_covid_violations.head()
# Out:
#    Request #  Status Request Type      Subrequest Type  \
# 0     346122  Closed     COVID-19  COVID-19 Violations
# 1     339374  Closed     COVID-19  COVID-19 Violations
# 2     343513  Closed     COVID-19  COVID-19 Violations
# 3     442996  Closed     COVID-19  COVID-19 Violations
# 4     339423  Closed     COVID-19  COVID-19 Violations
#
#   Additional Subrequest Type      Date / Time Opened      Date / Time Closed  \
# 0        COVID-19 Violations  04/15/2020 11:33:26 AM  04/16/2020 02:55:01 PM
# 1        COVID-19 Violations  04/04/2020 06:13:59 PM  04/09/2020 01:07:22 PM
# 2        COVID-19 Violations  04/10/2020 10:40:08 AM  04/14/2020 07:39:09 PM
# 3        COVID-19 Violations  08/12/2020 02:05:29 AM  08/12/2020 04:03:35 PM
# 4        COVID-19 Violations  04/04/2020 08:12:27 PM  04/09/2020 02:21:09 PM
#
#            Request Origin System of Origin ID Contact Type  ...  \
# 0  hubNashville Community                 NaN          NaN  ...
# 1  hubNashville Community                 NaN          NaN  ...
# 2  hubNashville Community                 NaN          NaN  ...
# 3  hubNashville Community                 NaN          NaN  ...
# 4  hubNashville Community                 NaN          NaN  ...
#
#    Parent Request  Closed When Created              Address       City  \
# 0             NaN                False        928 6th Ave S  NASHVILLE
# 1             NaN                False     500 Gallatin Ave  NASHVILLE
# 2             NaN                False  5720 Crossings Blvd        NaN
# 3             NaN                False        7689 Hwy 70 S  NASHVILLE
# 4             NaN                False      5310 Mt View Rd    ANTIOCH
#
#   Council District    ZIP   Latitude  Longitude  \
# 0             17.0  37203  36.149040 -86.772273
# 1              5.0  37206  36.181548 -86.749695
# 2              NaN    NaN  36.039608 -86.646541
# 3             22.0  37221  36.078933 -86.953400
# 4             32.0  37013  36.048182 -86.648447
#
#                     Mapped Location        date
# 0  (36.1490396, -86.77227289999999)  2020-04-15
# 1           (36.181548, -86.749695)  2020-04-04
# 2           (36.039608, -86.646541)  2020-04-10
# 3  (36.07893290000001, -86.9533998)  2020-08-12
# 4         (36.0481819, -86.6484474)  2020-04-04
#
# [5 rows x 22 columns]

# %%
hubnash_covid_violations['datetime'] = pd.DatetimeIndex(hubnash_covid_violations['date'])
hubnash_covid_violations.head()
# Out:
#    Request #  Status Request Type      Subrequest Type  \
# 0     346122  Closed     COVID-19  COVID-19 Violations
# 1     339374  Closed     COVID-19  COVID-19 Violations
# 2     343513  Closed     COVID-19  COVID-19 Violations
# 3     442996  Closed     COVID-19  COVID-19 Violations
# 4     339423  Closed     COVID-19  COVID-19 Violations
#
#   Additional Subrequest Type      Date / Time Opened      Date / Time Closed  \
# 0        COVID-19 Violations  04/15/2020 11:33:26 AM  04/16/2020 02:55:01 PM
# 1        COVID-19 Violations  04/04/2020 06:13:59 PM  04/09/2020 01:07:22 PM
# 2        COVID-19 Violations  04/10/2020 10:40:08 AM  04/14/2020 07:39:09 PM
# 3        COVID-19 Violations  08/12/2020 02:05:29 AM  08/12/2020 04:03:35 PM
# 4        COVID-19 Violations  04/04/2020 08:12:27 PM  04/09/2020 02:21:09 PM
#
#            Request Origin System of Origin ID Contact Type  ...  \
# 0  hubNashville Community                 NaN          NaN  ...
# 1  hubNashville Community                 NaN          NaN  ...
# 2  hubNashville Community                 NaN          NaN  ...
# 3  hubNashville Community                 NaN          NaN  ...
# 4  hubNashville Community                 NaN          NaN  ...
#
#    Closed When Created              Address       City  Council District  \
# 0                False        928 6th Ave S  NASHVILLE              17.0
# 1                False     500 Gallatin Ave  NASHVILLE               5.0
# 2                False  5720 Crossings Blvd        NaN               NaN
# 3                False        7689 Hwy 70 S  NASHVILLE              22.0
# 4                False      5310 Mt View Rd    ANTIOCH              32.0
#
#      ZIP   Latitude  Longitude                   Mapped Location        date  \
# 0  37203  36.149040 -86.772273  (36.1490396, -86.77227289999999)  2020-04-15
# 1  37206  36.181548 -86.749695           (36.181548, -86.749695)  2020-04-04
# 2    NaN  36.039608 -86.646541           (36.039608, -86.646541)  2020-04-10
# 3  37221  36.078933 -86.953400  (36.07893290000001, -86.9533998)  2020-08-12
# 4  37013  36.048182 -86.648447         (36.0481819, -86.6484474)  2020-04-04
#
#     datetime
# 0 2020-04-15
# 1 2020-04-04
# 2 2020-04-10
# 3 2020-08-12
# 4 2020-04-04
#
# [5 rows x 23 columns]

# %%
hubnash_covid_violations.dtypes
# Out:
# Request #                              int64
# Status                                object
# Request Type                          object
# Subrequest Type                       object
# Additional Subrequest Type            object
# Date / Time Opened                    object
# Date / Time Closed                    object
# Request Origin                        object
# System of Origin ID                   object
# Contact Type                          object
# Preferred Language                   float64
# State Issue                             bool
# Parent Request                       float64
# Closed When Created                     bool
# Address                               object
# City                                  object
# Council District                     float64
# ZIP                                   object
# Latitude                             float64
# Longitude                            float64
# Mapped Location                       object
# date                                  object
# datetime                      datetime64[ns]
# dtype: object

# %%
hubnash_covid_violations = hubnash_covid_violations.drop(columns=['Request #', 'Request Origin', 'System of Origin ID', 'Contact Type', 'date'])
hubnash_covid_violations.head()
# Out:
#    Status Request Type      Subrequest Type Additional Subrequest Type  \
# 0  Closed     COVID-19  COVID-19 Violations        COVID-19 Violations
# 1  Closed     COVID-19  COVID-19 Violations        COVID-19 Violations
# 2  Closed     COVID-19  COVID-19 Violations        COVID-19 Violations
# 3  Closed     COVID-19  COVID-19 Violations        COVID-19 Violations
# 4  Closed     COVID-19  COVID-19 Violations        COVID-19 Violations
#
#        Date / Time Opened      Date / Time Closed  Preferred Language  \
# 0  04/15/2020 11:33:26 AM  04/16/2020 02:55:01 PM                 NaN
# 1  04/04/2020 06:13:59 PM  04/09/2020 01:07:22 PM                 NaN
# 2  04/10/2020 10:40:08 AM  04/14/2020 07:39:09 PM                 NaN
# 3  08/12/2020 02:05:29 AM  08/12/2020 04:03:35 PM                 NaN
# 4  04/04/2020 08:12:27 PM  04/09/2020 02:21:09 PM                 NaN
#
#    State Issue  Parent Request  Closed When Created              Address  \
# 0        False             NaN                False        928 6th Ave S
# 1        False             NaN                False     500 Gallatin Ave
# 2        False             NaN                False  5720 Crossings Blvd
# 3        False             NaN                False        7689 Hwy 70 S
# 4        False             NaN                False      5310 Mt View Rd
#
#         City  Council District    ZIP   Latitude  Longitude  \
# 0  NASHVILLE              17.0  37203  36.149040 -86.772273
# 1  NASHVILLE               5.0  37206  36.181548 -86.749695
# 2        NaN               NaN    NaN  36.039608 -86.646541
# 3  NASHVILLE              22.0  37221  36.078933 -86.953400
# 4    ANTIOCH              32.0  37013  36.048182 -86.648447
#
#                     Mapped Location   datetime
# 0  (36.1490396, -86.77227289999999) 2020-04-15
# 1           (36.181548, -86.749695) 2020-04-04
# 2           (36.039608, -86.646541) 2020-04-10
# 3  (36.07893290000001, -86.9533998) 2020-08-12
# 4         (36.0481819, -86.6484474) 2020-04-04

# %%
hubnash_covid_violations_sorted = hubnash_covid_violations.sort_values(by='datetime')
hubnash_covid_violations_sorted.head()
# Out:
#       Status Request Type      Subrequest Type Additional Subrequest Type  \
# 8897  Closed     COVID-19  COVID-19 Violations        COVID-19 Violations
# 8913  Closed     COVID-19  COVID-19 Violations        COVID-19 Violations
# 8910  Closed     COVID-19  COVID-19 Violations        COVID-19 Violations
# 333      New     COVID-19  COVID-19 Violations        COVID-19 Violations
# 8912  Closed     COVID-19  COVID-19 Violations        COVID-19 Violations
#
#           Date / Time Opened      Date / Time Closed  Preferred Language  \
# 8897  03/29/2020 08:35:22 PM  04/13/2020 03:42:57 PM                 NaN
# 8913  03/30/2020 09:50:24 PM  04/10/2020 05:08:54 PM                 NaN
# 8910  03/31/2020 05:27:19 PM  04/09/2020 07:28:17 PM                 NaN
# 333   03/31/2020 09:20:41 PM                     NaN                 NaN
# 8912  03/31/2020 03:39:32 AM  04/09/2020 07:27:50 PM                 NaN
#
#       State Issue  Parent Request  Closed When Created           Address  \
# 8897        False             NaN                False  12 E Thompson Ln
# 8913        False             NaN                False    700 12th Ave S
# 8910        False             NaN                False    409 Harding Pl
# 333         False             NaN                False               NaN
# 8912        False             NaN                False   384 Thompson Ln
#
#            City  Council District    ZIP  Latitude  Longitude  \
# 8897  NASHVILLE              16.0  37211  36.11591  -86.71984
# 8913  NASHVILLE              19.0  37203  36.15062  -86.78397
# 8910  NASHVILLE              26.0  37211  36.07834  -86.72724
# 333         NaN               NaN    NaN       NaN        NaN
# 8912  NASHVILLE              16.0  37211  36.11204  -86.74373
#
#             Mapped Location   datetime
# 8897  (36.11591, -86.71984) 2020-03-29
# 8913  (36.15062, -86.78397) 2020-03-30
# 8910  (36.07834, -86.72724) 2020-03-31
# 333                     NaN 2020-03-31
# 8912  (36.11204, -86.74373) 2020-03-31

# %%
#Get the month change to datetimeto datetime format
hubnash_covid_violations_sorted['month'] = pd.DatetimeIndex(hubnash_covid_violations_sorted['datetime']).month
hubnash_covid_violations_sorted.head()
# Out:
#       Status Request Type      Subrequest Type Additional Subrequest Type  \
# 8897  Closed     COVID-19  COVID-19 Violations        COVID-19 Violations
# 8913  Closed     COVID-19  COVID-19 Violations        COVID-19 Violations
# 8910  Closed     COVID-19  COVID-19 Violations        COVID-19 Violations
# 333      New     COVID-19  COVID-19 Violations        COVID-19 Violations
# 8912  Closed     COVID-19  COVID-19 Violations        COVID-19 Violations
#
#           Date / Time Opened      Date / Time Closed  Preferred Language  \
# 8897  03/29/2020 08:35:22 PM  04/13/2020 03:42:57 PM                 NaN
# 8913  03/30/2020 09:50:24 PM  04/10/2020 05:08:54 PM                 NaN
# 8910  03/31/2020 05:27:19 PM  04/09/2020 07:28:17 PM                 NaN
# 333   03/31/2020 09:20:41 PM                     NaN                 NaN
# 8912  03/31/2020 03:39:32 AM  04/09/2020 07:27:50 PM                 NaN
#
#       State Issue  Parent Request  Closed When Created           Address  \
# 8897        False             NaN                False  12 E Thompson Ln
# 8913        False             NaN                False    700 12th Ave S
# 8910        False             NaN                False    409 Harding Pl
# 333         False             NaN                False               NaN
# 8912        False             NaN                False   384 Thompson Ln
#
#            City  Council District    ZIP  Latitude  Longitude  \
# 8897  NASHVILLE              16.0  37211  36.11591  -86.71984
# 8913  NASHVILLE              19.0  37203  36.15062  -86.78397
# 8910  NASHVILLE              26.0  37211  36.07834  -86.72724
# 333         NaN               NaN    NaN       NaN        NaN
# 8912  NASHVILLE              16.0  37211  36.11204  -86.74373
#
#             Mapped Location   datetime  month
# 8897  (36.11591, -86.71984) 2020-03-29      3
# 8913  (36.15062, -86.78397) 2020-03-30      3
# 8910  (36.07834, -86.72724) 2020-03-31      3
# 333                     NaN 2020-03-31      3
# 8912  (36.11204, -86.74373) 2020-03-31      3

# %%
hubnash_davidson_violations_bymonth = hubnash_covid_violations_sorted.groupby('month')['Date / Time Opened'].count().reset_index()
hubnash_davidson_violations_bymonth
# Out:
#    month  Date / Time Opened
# 0      3                  10
# 1      4                2421
# 2      5                1469
# 3      6                1666
# 4      7                2738
# 5      8                1661
# 6      9                 687
# 7     10                 879
# 8     11                 357

# %%
#Create subplot using Lydia's code
#note for plotting exploration analysis https://towardsdatascience.com/data-visualization-cheat-sheet-with-seaborn-and-matplotlib-70cac11c6517
sns.set_style('whitegrid')
fig,ax=plt.subplots(figsize=(16,7))
#Create lineplot
chart=sns.lineplot(x=hubnash_davidson_violations_bymonth['month'], y=hubnash_davidson_violations_bymonth['Date / Time Opened'],ax=ax)
sns.despine(left=True)

#Customize chart
chart.set_xlabel('Month',weight='bold',fontsize=13)
chart.set_ylabel('Cases', weight='bold',fontsize=13)
chart.set_title('Monthly Covid Violation Report Counts',weight='bold',fontsize=16)
chart.set_xticklabels(['','March','April','May','June','July','August','September','October','November'], rotation = 45, ha="right")
# Out:
# [Text(0, 0, ''),
#  Text(0, 0, 'March'),
#  Text(0, 0, 'April'),
#  Text(0, 0, 'May'),
#  Text(0, 0, 'June'),
#  Text(0, 0, 'July'),
#  Text(0, 0, 'August'),
#  Text(0, 0, 'September'),
#  Text(0, 0, 'October'),
#  Text(0, 0, 'November')]

# %%
cases_and_violations = pd.merge(davidson_cases_bydate, hubnash_davidson_violations_bymonth,
                               on=['month'], how = 'outer')
cases_and_violations
# Out:
#    month  cases  Date / Time Opened
# 0      3    541                  10
# 1      4   2669                2421
# 2      5   5285                1469
# 3      6   9805                1666
# 4      7  21060                2738
# 5      8  25975                1661
# 6      9  29005                 687
# 7     10  34900                 879
# 8     11  40433                 357

# %%
# plotting 2 dataframes on one plot. davidson_cases_bydate and hubnash_davidson_violations_bymonth

# davidson cases chart code
sns.set_style('whitegrid')
fig,ax=plt.subplots(figsize=(16,7))
#Create lineplot
chart=sns.lineplot(data= cases_and_violations, ax=ax)
sns.despine(left=True)


#Customize chart
chart.set_xlabel('Month',weight='bold',fontsize=13)
chart.set_ylabel('Cases and Violations', weight='bold',fontsize=13)
chart.set_title('Monthly Covid Cases vs. Covid Violation Report Counts in Davidson County',weight='bold',fontsize=16)
chart.set_xticklabels(['','March','April','May','June','July','August','September','October','November'], rotation = 45, ha="right")
# Out:
# [Text(0, 0, ''),
#  Text(0, 0, 'March'),
#  Text(0, 0, 'April'),
#  Text(0, 0, 'May'),
#  Text(0, 0, 'June'),
#  Text(0, 0, 'July'),
#  Text(0, 0, 'August'),
#  Text(0, 0, 'September'),
#  Text(0, 0, 'October'),
#  Text(0, 0, 'November')]

# %%
cases_and_violations.to_csv('../data/cases_and_violations.csv')
