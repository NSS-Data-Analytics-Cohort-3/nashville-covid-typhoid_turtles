# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
import time
import numpy as np

# %%
cluster_frame = pd.read_csv('../data/violation_distance.csv')
cluster_frame.head()
# Out:
#    Unnamed: 0                   Cluster Name     Facility Type  \
# 0           0             Vanderbilt Parties  Social Gathering
# 1          58                   Miss Kelli's               Bar
# 2          31                      Tootsie's               Bar
# 3          29  Kid Rock's Big Ass Honky Tonk               Bar
# 4          28                        Dogwood        Restaurant
#
#   Cluster Start Date  # Cases   Latitude  Longitude   violation_address  \
# 0          3/11/2020       49  36.144703 -86.802655   2201 West End Ave
# 1          10/1/2020       14  36.164369 -86.778515  207 Printers Alley
# 2          6/26/2020       27  36.160769 -86.778210        422 Broadway
# 3          6/26/2020       15  36.161446 -86.775726        221 Broadway
# 4          6/26/2020       19  36.149811 -86.796336    1907 Division St
#
#    violation_lat  violation_lon  violation_distance  violation_match color
# 0      36.144703     -86.802655                 0.0  Violation Match   red
# 1      36.164369     -86.778515                 0.0  Violation Match   red
# 2      36.160769     -86.778210                 0.0  Violation Match   red
# 3      36.161446     -86.775726                 0.0  Violation Match   red
# 4      36.149811     -86.796336                 0.0  Violation Match   red

# %%
geometry = [Point(xy) for xy in zip(cluster_frame.Longitude, cluster_frame.Latitude)]
# cluster_frame = cluster_frame.drop(['Latitude', 'Longitude'], axis=1)
cluster_geo = gpd.GeoDataFrame(cluster_frame, crs="EPSG:4326", geometry=geometry)

# %%
cluster_map = folium.Map(location = [36.16713345170994, -86.76850874477554], zoom_start = 12)
folium.TileLayer('stamentoner').add_to(cluster_map)

# %%
cluster_frame.head()
# Out:
#    Unnamed: 0                   Cluster Name     Facility Type  \
# 0           0             Vanderbilt Parties  Social Gathering
# 1          58                   Miss Kelli's               Bar
# 2          31                      Tootsie's               Bar
# 3          29  Kid Rock's Big Ass Honky Tonk               Bar
# 4          28                        Dogwood        Restaurant
#
#   Cluster Start Date  # Cases   Latitude  Longitude   violation_address  \
# 0          3/11/2020       49  36.144703 -86.802655   2201 West End Ave
# 1          10/1/2020       14  36.164369 -86.778515  207 Printers Alley
# 2          6/26/2020       27  36.160769 -86.778210        422 Broadway
# 3          6/26/2020       15  36.161446 -86.775726        221 Broadway
# 4          6/26/2020       19  36.149811 -86.796336    1907 Division St
#
#    violation_lat  violation_lon  violation_distance  violation_match color  \
# 0      36.144703     -86.802655                 0.0  Violation Match   red
# 1      36.164369     -86.778515                 0.0  Violation Match   red
# 2      36.160769     -86.778210                 0.0  Violation Match   red
# 3      36.161446     -86.775726                 0.0  Violation Match   red
# 4      36.149811     -86.796336                 0.0  Violation Match   red
#
#                      geometry
# 0  POINT (-86.80266 36.14470)
# 1  POINT (-86.77851 36.16437)
# 2  POINT (-86.77821 36.16077)
# 3  POINT (-86.77573 36.16145)
# 4  POINT (-86.79634 36.14981)

# %%
for row_index, row_values in cluster_geo.iterrows():
    loc = [row_values['Latitude'], row_values['Longitude']]
    pop = 'Outbreak cluster: ' + row_values['Cluster Name']
    marker = folium.Marker(
        location = loc,
        icon = folium.Icon(color="red",icon="medkit", prefix='fa'),
#        radius=100,
        popup = pop,
        fill=True,
        color='red') 
    
    marker.add_to(cluster_map)
    
cluster_map.save('../maps/cluster_map.html')
cluster_map

# %%
for row_index, row_values in cluster_geo.iterrows():
    loc = [row_values['violation_lat'], row_values['violation_lon']]
#    pop = row_values['Cluster Name']
    marker = folium.Circle(
        location = loc,
        radius=200,
#        popup = pop,
        fill=True,
        color='blue') 
    
    marker.add_to(cluster_map)
    
cluster_map.save('../maps/cluster_map.html')
cluster_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
