# %%
import pandas as pd
from sqlalchemy import create_engine
from credentials import user, password, server
import numpy as np
from math import radians, cos, sin, asin, sqrt

# %%
engine = create_engine("postgres+psycopg2://"+user+":"+password+"@"\
                       +server+":5432/covid_data")

# %%
colleges = pd.read_sql("SELECT * FROM colleges;", con=engine)
counties = pd.read_sql("SELECT * FROM counties;", con=engine)
mask_use = pd.read_sql("SELECT * FROM mask_use;", con=engine)
states = pd.read_sql("SELECT * FROM states;", con=engine)
us_totals = pd.read_sql("SELECT * FROM us_totals;", con=engine)

business = pd.read_csv('../data/businesses.csv')
clusters = pd.read_csv('../data/clusters.csv')
hubnash = pd.read_csv('../data/hubNashville_311_Service_Requests.csv', low_memory=False)
hubnash = hubnash[(hubnash['Subrequest Type'] == 'COVID-19 Violations')]

hubnash = hubnash[hubnash['Latitude'].notna()]
clusters = clusters[clusters['Latitude'].notna()]

# %%
business.head()
# Out:
#                             address                          vicinity  \
# 0   2440 COUCHVILLE PIKE, Nashville   2440 Couchville Pike, Nashville
# 1       1613 Buchanan St, Nashville   1613 Buchanan Street, Nashville
# 2       1613 Buchanan St, Nashville   1613 Buchanan Street, Nashville
# 3       1613 Buchanan St, Nashville   1613 Buchanan Street, Nashville
# 4  306 White Bridge Pike, Nashville  306 White Bridge Pike, Nashville
#
#                                  name  \
# 0            Wilson Sporting Goods Co
# 1              Coin Cloud Bitcoin ATM
# 2                      Discounts Mart
# 3                   Northwest Liquors
# 4  Suds Up Car Wash of West Nashville
#
#                                                 type
# 0             ['point_of_interest', 'establishment']
# 1  ['atm', 'finance', 'point_of_interest', 'estab...
# 2  ['convenience_store', 'food', 'point_of_intere...
# 3  ['liquor_store', 'point_of_interest', 'store',...
# 4  ['car_wash', 'point_of_interest', 'establishme...

# %%
clusters.head()
# Out:
#                             Cluster Name         Facility Type  \
# 0                     Vanderbilt Parties      Social Gathering
# 1               Event at Clementine Hall      Social Gathering
# 3    The Health Center at Richland Place                  LTCF
# 4  Trevecca Center for Rehab and Healing                  LTCF
# 5                            Tyson Foods  Commercial-Warehouse
#
#   Cluster Start Date  # Cases   Latitude  Longitude
# 0          3/11/2020       49  36.144703 -86.802655
# 1          3/14/2020       23  36.152444 -86.844583
# 3           4/3/2020       47  36.128750 -86.817345
# 4           4/4/2020      102  36.144562 -86.754560
# 5           4/6/2020      280  36.331015 -86.709977

# %%
hubnash.head()
# Out:
#      Request #  Status Request Type      Subrequest Type  \
# 61      346122  Closed     COVID-19  COVID-19 Violations
# 95      339374  Closed     COVID-19  COVID-19 Violations
# 110     343513  Closed     COVID-19  COVID-19 Violations
# 113     442996  Closed     COVID-19  COVID-19 Violations
# 118     339423  Closed     COVID-19  COVID-19 Violations
#
#     Additional Subrequest Type      Date / Time Opened  \
# 61         COVID-19 Violations  04/15/2020 11:33:26 AM
# 95         COVID-19 Violations  04/04/2020 06:13:59 PM
# 110        COVID-19 Violations  04/10/2020 10:40:08 AM
# 113        COVID-19 Violations  08/12/2020 02:05:29 AM
# 118        COVID-19 Violations  04/04/2020 08:12:27 PM
#
#          Date / Time Closed          Request Origin System of Origin ID  \
# 61   04/16/2020 02:55:01 PM  hubNashville Community                 NaN
# 95   04/09/2020 01:07:22 PM  hubNashville Community                 NaN
# 110  04/14/2020 07:39:09 PM  hubNashville Community                 NaN
# 113  08/12/2020 04:03:35 PM  hubNashville Community                 NaN
# 118  04/09/2020 02:21:09 PM  hubNashville Community                 NaN
#
#     Contact Type  ...  State Issue  Parent Request  Closed When Created  \
# 61           NaN  ...        False             NaN                False
# 95           NaN  ...        False             NaN                False
# 110          NaN  ...        False             NaN                False
# 113          NaN  ...        False             NaN                False
# 118          NaN  ...        False             NaN                False
#
#                  Address       City Council District    ZIP   Latitude  \
# 61         928 6th Ave S  NASHVILLE             17.0  37203  36.149040
# 95      500 Gallatin Ave  NASHVILLE              5.0  37206  36.181548
# 110  5720 Crossings Blvd        NaN              NaN    NaN  36.039608
# 113        7689 Hwy 70 S  NASHVILLE             22.0  37221  36.078933
# 118      5310 Mt View Rd    ANTIOCH             32.0  37013  36.048182
#
#      Longitude                   Mapped Location
# 61  -86.772273  (36.1490396, -86.77227289999999)
# 95  -86.749695           (36.181548, -86.749695)
# 110 -86.646541           (36.039608, -86.646541)
# 113 -86.953400  (36.07893290000001, -86.9533998)
# 118 -86.648447         (36.0481819, -86.6484474)
#
# [5 rows x 21 columns]

# %%
def dist(lat1, long1, lat2, long2):
    # convert decimal degrees to radians 
    lat1, long1, lat2, long2 = map(radians, [lat1, long1, lat2, long2])
    # haversine formula 
    dlon = long2 - long1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    # Radius of earth in kilometers is 6371
    km = 6371* c
    return km

# %%
def find_nearest(lat, long):
    distances = hubnash.apply(
        lambda row: dist(lat, long, row['Latitude'], row['Longitude']), 
        axis=1)
    return hubnash.loc[distances.idxmin(), 'Address']

clusters['violation_address'] = clusters.apply(
    lambda row: find_nearest(row['Latitude'], row['Longitude']), 
    axis=1)

clusters.head()
# Out:
#                             Cluster Name         Facility Type  \
# 0                     Vanderbilt Parties      Social Gathering
# 1               Event at Clementine Hall      Social Gathering
# 3    The Health Center at Richland Place                  LTCF
# 4  Trevecca Center for Rehab and Healing                  LTCF
# 5                            Tyson Foods  Commercial-Warehouse
#
#   Cluster Start Date  # Cases   Latitude  Longitude  \
# 0          3/11/2020       49  36.144703 -86.802655
# 1          3/14/2020       23  36.152444 -86.844583
# 3           4/3/2020       47  36.128750 -86.817345
# 4           4/4/2020      102  36.144562 -86.754560
# 5           4/6/2020      280  36.331015 -86.709977
#
#                violation_address
# 0              2201 West End Ave
# 1             4710 Charlotte Ave
# 3  Elmington Ave & Sharondale Dr
# 4          329 Murfreesboro Pike
# 5              201 Cartwright St

# %%
def find_nearest(lat, long):
    distances = hubnash.apply(
        lambda row: dist(lat, long, row['Latitude'], row['Longitude']), 
        axis=1)
    return hubnash.loc[distances.idxmin(), 'Latitude']

clusters['violation_lat'] = clusters.apply(
    lambda row: find_nearest(row['Latitude'], row['Longitude']), 
    axis=1)

clusters.head()
# Out:
#                             Cluster Name         Facility Type  \
# 0                     Vanderbilt Parties      Social Gathering
# 1               Event at Clementine Hall      Social Gathering
# 3    The Health Center at Richland Place                  LTCF
# 4  Trevecca Center for Rehab and Healing                  LTCF
# 5                            Tyson Foods  Commercial-Warehouse
#
#   Cluster Start Date  # Cases   Latitude  Longitude  \
# 0          3/11/2020       49  36.144703 -86.802655
# 1          3/14/2020       23  36.152444 -86.844583
# 3           4/3/2020       47  36.128750 -86.817345
# 4           4/4/2020      102  36.144562 -86.754560
# 5           4/6/2020      280  36.331015 -86.709977
#
#                violation_address  violation_lat
# 0              2201 West End Ave      36.144703
# 1             4710 Charlotte Ave      36.152444
# 3  Elmington Ave & Sharondale Dr      36.128018
# 4          329 Murfreesboro Pike      36.144560
# 5              201 Cartwright St      36.331373

# %%
def find_nearest(lat, long):
    distances = hubnash.apply(
        lambda row: dist(lat, long, row['Latitude'], row['Longitude']), 
        axis=1)
    return hubnash.loc[distances.idxmin(), 'Longitude']

clusters['violation_lon'] = clusters.apply(
    lambda row: find_nearest(row['Latitude'], row['Longitude']), 
    axis=1)

clusters.head()
# Out:
#                             Cluster Name         Facility Type  \
# 0                     Vanderbilt Parties      Social Gathering
# 1               Event at Clementine Hall      Social Gathering
# 3    The Health Center at Richland Place                  LTCF
# 4  Trevecca Center for Rehab and Healing                  LTCF
# 5                            Tyson Foods  Commercial-Warehouse
#
#   Cluster Start Date  # Cases   Latitude  Longitude  \
# 0          3/11/2020       49  36.144703 -86.802655
# 1          3/14/2020       23  36.152444 -86.844583
# 3           4/3/2020       47  36.128750 -86.817345
# 4           4/4/2020      102  36.144562 -86.754560
# 5           4/6/2020      280  36.331015 -86.709977
#
#                violation_address  violation_lat  violation_lon  \
# 0              2201 West End Ave      36.144703     -86.802655
# 1             4710 Charlotte Ave      36.152444     -86.844583
# 3  Elmington Ave & Sharondale Dr      36.128018     -86.816838
# 4          329 Murfreesboro Pike      36.144560     -86.754560
# 5              201 Cartwright St      36.331373     -86.711044
#
#    violation_distance
# 0          -86.802655
# 1          -86.844583
# 3          -86.816838
# 4          -86.754560
# 5          -86.711044

# %%
clusters['violation_distance'] = clusters.apply(
    lambda row: dist(row['Latitude'], row['Longitude'], row['violation_lat'], row['violation_lon']), 
    axis=1) * 0.6213712

clusters.head()
# Out:
#                             Cluster Name         Facility Type  \
# 0                     Vanderbilt Parties      Social Gathering
# 1               Event at Clementine Hall      Social Gathering
# 3    The Health Center at Richland Place                  LTCF
# 4  Trevecca Center for Rehab and Healing                  LTCF
# 5                            Tyson Foods  Commercial-Warehouse
#
#   Cluster Start Date  # Cases   Latitude  Longitude  \
# 0          3/11/2020       49  36.144703 -86.802655
# 1          3/14/2020       23  36.152444 -86.844583
# 3           4/3/2020       47  36.128750 -86.817345
# 4           4/4/2020      102  36.144562 -86.754560
# 5           4/6/2020      280  36.331015 -86.709977
#
#                violation_address  violation_lat  violation_lon  \
# 0              2201 West End Ave      36.144703     -86.802655
# 1             4710 Charlotte Ave      36.152444     -86.844583
# 3  Elmington Ave & Sharondale Dr      36.128018     -86.816838
# 4          329 Murfreesboro Pike      36.144560     -86.754560
# 5              201 Cartwright St      36.331373     -86.711044
#
#    violation_distance
# 0            0.000000
# 1            0.000000
# 3            0.057928
# 4            0.000159
# 5            0.064339

# %%
clusters = clusters.sort_values(by='violation_distance', ascending=False)
clusters.head()
# Out:
#                     Cluster Name      Facility Type Cluster Start Date  \
# 24              West Meade Place               LTCF          6/24/2020
# 11       Knowles Assisted Living               LTCF          4/27/2020
# 33                  Men of Valor  Congregate Living           7/1/2020
# 40  Middle TN Mental Health Inst  Congregate Living          7/29/2020
# 37   NHC Place at the Trace ACLF               LTCF          7/14/2020
#
#     # Cases   Latitude  Longitude            violation_address  violation_lat  \
# 24       11  36.103424 -86.888650           6216 Robin Hill Rd      36.107167
# 11       41  36.181554 -86.848928                3337 Cocoa Dr      36.185451
# 33       10  36.061543 -86.669342  Blue Hole Rd & Antioch Pike      36.059970
# 40       48  36.163999 -86.647347      256 Stewarts Ferry Pike      36.161831
# 37       14  36.035223 -86.966196               5948 Pasquo Rd      36.034869
#
#     violation_lon  violation_distance
# 24     -86.883087            0.404145
# 11     -86.846332            0.305684
# 33     -86.672120            0.189422
# 40     -86.647441            0.149825
# 37     -86.968782            0.146510
